# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# # loading the dataset from keras

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
len(X_train)
# Out:
# 60000

# %%
len(X_test)
# Out:
# 10000

# %% [markdown]
# # plotting the digit as image

# %%
plt.matshow(X_train[2])

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # Reshaping the dataset from the a 28-28 array to a 1D array of 784-1

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %% [markdown]
# # using keras to fit the data and tensorboard for visualisation

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])



model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 971us/step - loss: 0.8826 - accuracy: 0.7811
# Epoch 2/5
# 1875/1875 [==============================] - 2s 930us/step - loss: 0.3595 - accuracy: 0.9020
# Epoch 3/5
# 1875/1875 [==============================] - 2s 918us/step - loss: 0.3060 - accuracy: 0.9152
# Epoch 4/5
# 1875/1875 [==============================] - 2s 943us/step - loss: 0.2752 - accuracy: 0.9227
# Epoch 5/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2525 - accuracy: 0.9304

# %% [markdown]
# # Accuracy

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 759us/step - loss: 0.2332 - accuracy: 0.9339
# [0.2331608682870865, 0.933899998664856]
